# %% [markdown]
# # Hidden Links Analysis using Clustering & switching to a node of same cluster

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading dataset

# %%
from ReadingDataSet import ReadingDataSet
from os import mkdir
from os.path import exists
import pickle

dataSet = ReadingDataSet()
# Dictionary containing all dataframes
All_dfs = dataSet.All_dfs
# Out:
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# d:\This is My file\Dr.Mervat Internship\Clustring task\CheckSynonymForColumns.py:41: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   storePercentages[newColumns[j]] = doc1.similarity(doc2)
# Index(['IntOrders_id', 'IntShip_id', 'quantity', 'placed_when', 'actual_date',
#        'expected_date', 'cost', 'status'],
#       dtype='object')
# manufacturing Different_suppliers
# products warehouses
# warehouses product_types
# Index(['retailer_id', 'country', 'city_name', 'type', 'reviews_number',
#        'retailer_types', 'rating', 'opening_hours', 'capacity (units)',
#        'products_sold'],
#       dtype='object')

# %% [markdown]
# ## Nodes and Edges dataframes

# %%
myedges = pd.read_csv("myedges.csv", index_col=0)
mynodes = pd.read_csv("mynodes.csv", index_col=0)

# %%
myedges
# Out:
#       From    To   From_Table     To_Table  Weight  Rental price  \
# 0     1240  1600     Supplier    Ssintship      10             0
# 1     1600  1164    Ssintship     Supplier      20             0
# 2     1159  1601     Supplier    Ssintship      10             0
# 3     1601  1072    Ssintship     Supplier      35             0
# 4     1126  1602     Supplier    Ssintship      10             0
# ...    ...   ...          ...          ...     ...           ...
# 8115  5907  3114  Ssintorders     Products      70             0
# 8116  2135  5908    Ssintship  Ssintorders      10             0
# 8117  5908  2966  Ssintorders     Products      90             0
# 8118  2136  5909    Ssintship  Ssintorders      10             0
# 8119  5909  3125  Ssintorders     Products      55             0
#
#       Transportation_distance  Type    price  profit_margin (%)  \
# 0                           0     0     0.00                  0
# 1                           0     0     0.00                  0
# 2                           0     0     0.00                  0
# 3                           0     0     0.00                  0
# 4                           0     0     0.00                  0
# ...                       ...   ...      ...                ...
# 8115                        0     0   132.72                 40
# 8116                        0     0     0.00                  0
# 8117                        0     0  7040.86                 29
# 8118                        0     0     0.00                  0
# 8119                        0     0    72.83                 13
#
#       market_share (%)  Annual_sales       Edge_Name
# 0                    0          0.00       ssintship
# 1                   19          5.21       ssintship
# 2                    0          0.00       ssintship
# 3                   86         76.43       ssintship
# 4                    0          0.00       ssintship
# ...                ...           ...             ...
# 8115                 0          0.00  Orders_Prodcut
# 8116                 0          0.00           Order
# 8117                 0          0.00  Orders_Prodcut
# 8118                 0          0.00           Order
# 8119                 0          0.00  Orders_Prodcut
#
# [8120 rows x 13 columns]

# %%
mynodes
# Out:
#             Label     ID                                         Attributes
# 0        supplier  34258  {'supplier_name': 'Taylor PLC', 'country': "La...
# 1        supplier  40868  {'supplier_name': 'Sorrentino SPA', 'country':...
# 2        supplier  27813  {'supplier_name': 'Persico e figli', 'country'...
# 3        supplier  57551  {'supplier_name': 'Karge OHG mbH', 'country': ...
# 4        supplier  50099  {'supplier_name': 'Smith, Porter and Lynch', '...
# ...           ...    ...                                                ...
# 5905  ssintorders  10448  {'quantity': 766, 'placed_when': '1993-05-08',...
# 5906  ssintorders  10449  {'quantity': 766, 'placed_when': '1993-05-08',...
# 5907  ssintorders  10450  {'quantity': 766, 'placed_when': '1993-05-08',...
# 5908  ssintorders  10451  {'quantity': 766, 'placed_when': '1993-05-08',...
# 5909  ssintorders  10452  {'quantity': 766, 'placed_when': '1993-05-08',...
#
# [5910 rows x 3 columns]

# %% [markdown]
# ## Classes defined as Nodes

# %%
print(mynodes.Label.unique())
len(mynodes.Label.unique())
# Out:
# ['supplier' 'retailer' 'customer' 'warehouses' 'externaltransactions'
#  'internaltransactions' 'srintship' 'rcextship' 'scextship' 'ssintship'
#  'internalservices' 'rcextorders' 'facilities' 'externalservices'
#  'products' 'srintorders' 'scextorders' 'ssintorders']
# 18

# %%
all_nodes=dict()
for n in mynodes.Label.unique():
    all_nodes[f"{n}_nodes"]=(mynodes[(mynodes["Label"] ==n)])

all_nodes
# Out:
# {'supplier_nodes':         Label     ID                                         Attributes
#  0    supplier  34258  {'supplier_name': 'Taylor PLC', 'country': "La...
#  1    supplier  40868  {'supplier_name': 'Sorrentino SPA', 'country':...
#  2    supplier  27813  {'supplier_name': 'Persico e figli', 'country'...
#  3    supplier  57551  {'supplier_name': 'Karge OHG mbH', 'country': ...
#  4    supplier  50099  {'supplier_name': 'Smith, Porter and Lynch', '...
#  ..        ...    ...                                                ...
#  295  supplier  90256  {'supplier_name': 'Förster', 'country': 'Ethio...
#  296  supplier  35266  {'supplier_name': 'Gotthard Zahn GmbH', 'count...
#  297  supplier  52647  {'supplier_name': 'Cook-Webb', 'country': 'Mor...
#  298  supplier  13355  {'supplier_name': 'Shah-Lowe', 'country': 'Cen...
#  299  supplier  48467  {'supplier_name': 'Brandt Ltd', 'country': 'An...
#
#  [300 rows x 3 columns],
#  'retailer_nodes':         Label     ID                                         Attributes
#  300  retailer  91089  {'country': 'Tunisia', 'city_name': 'Kairouan'...
#  301  retailer  95444  {'country': 'Kuwait', 'city_name': 'Al Farwānī...
#  302  retailer  66051  {'country': 'Qatar', 'city_name': 'Ash Shīḩānī...
#  303  retailer  41072  {'country': 'Greece', 'city_name': 'Dytikí Mak...
#  304  retailer  34083  {'country': 'Gambia', 'city_name': 'Banjul', '...
#  ..        ...    ...                                                ...
#  445  retailer  86308  {'country': 'Ukraine', 'city_name': 'Chernihiv...
#  446  retailer  18464  {'country': 'Haiti', 'city_name': 'Grandans', ...
#  447  retailer  57039  {'country': "Lao People's Democratic Republic"...
#  448  retailer  33250  {'country': 'South Sudan', 'city_name': 'Lakes...
#  449  retailer  21789  {'country': 'Cyprus', 'city_name': 'Ammochosto...
#
#  [150 rows x 3 columns],
#  'customer_nodes':         Label     ID                                         Attributes
#  450  customer  33736  {'gender': 'F', 'first_name': 'Nadia', 'last_n...
#  451  customer  42959  {'gender': 'M', 'first_name': 'Eric', 'last_na...
#  452  customer  50653  {'gender': 'F', 'first_name': 'Alessia', 'last...
#  453  customer  82485  {'gender': 'M', 'first_name': 'Alexei', 'last_...
#  454  customer  56609  {'gender': 'F', 'first_name': 'Brenda', 'last_...
#  ..        ...    ...                                                ...
#  595  customer  82421  {'gender': 'F', 'first_name': 'Mary', 'last_na...
#  596  customer  14074  {'gender': 'F', 'first_name': 'Luce', 'last_na...
#  597  customer  95571  {'gender': 'M', 'first_name': 'Timothy', 'last...
#  598  customer  41209  {'gender': 'F', 'first_name': 'Emmi', 'last_na...
#  599  customer  47008  {'gender': 'F', 'first_name': 'Lauren', 'last_...
#
#  [150 rows x 3 columns],
#  'warehouses_nodes':            Label    ID                                         Attributes
#  600   warehouses  1012  {'country': 'Sierra Leone', 'city_name': 'East...
#  601   warehouses  1017  {'country': 'Réunion', 'city_name': 'Unknown',...
#  602   warehouses  1028  {'country': 'Malawi', 'city_name': 'Chitipa', ...
#  603   warehouses  1034  {'country': "Lao People's Democratic Republic"...
#  604   warehouses  1045  {'country': 'Cocos (Keeling) Islands', 'city_n...
#  ...          ...   ...                                                ...
#  1595  warehouses  9964  {'country': 'Norway', 'city_name': 'Jan Mayen ...
#  1596  warehouses  9970  {'country': 'Bouvet Island', 'city_name': 'Unk...
#  1597  warehouses  9975  {'country': 'Bolivia, Plurinational State of',...
#  1598  warehouses  9981  {'country': 'Qatar', 'city_name': 'Ash Shamāl'...
#  1599  warehouses  9996  {'country': 'Tunisia', 'city_name': 'Ben Arous...
#
#  [1000 rows x 3 columns],
#  'externaltransactions_nodes':                      Label    ID Attributes
#  1600  externaltransactions  2611         {}
#  1601  externaltransactions  7858         {}
#  1602  externaltransactions  4247         {}
#  1603  externaltransactions  2530         {}
#  1604  externaltransactions  3381         {}
#  ...                    ...   ...        ...
#  1695  externaltransactions  9232         {}
#  1696  externaltransactions  8429         {}
#  1697  externaltransactions  4926         {}
#  1698  externaltransactions  6209         {}
#  1699  externaltransactions  8719         {}
#
#  [100 rows x 3 columns],
#  'internaltransactions_nodes':                      Label    ID Attributes
#  1700  internaltransactions  7927         {}
#  1701  internaltransactions  8659         {}
#  1702  internaltransactions  2751         {}
#  1703  internaltransactions  3389         {}
#  1704  internaltransactions  3917         {}
#  ...                    ...   ...        ...
#  1795  internaltransactions  9055         {}
#  1796  internaltransactions  8775         {}
#  1797  internaltransactions  8685         {}
#  1798  internaltransactions  5939         {}
#  1799  internaltransactions  9269         {}
#
#  [100 rows x 3 columns],
#  'srintship_nodes':           Label    ID Attributes
#  1800  srintship  5897         {}
#  1801  srintship  2360         {}
#  1802  srintship  6209         {}
#  1803  srintship  1480         {}
#  1804  srintship  2887         {}
#  1805  srintship  2838         {}
#  1806  srintship  8010         {}
#  1807  srintship  8144         {}
#  1808  srintship  2907         {}
#  1809  srintship  4214         {}
#  1810  srintship  1388         {}
#  1811  srintship  5718         {}
#  1812  srintship  1851         {}
#  1813  srintship  2396         {}
#  1814  srintship  4671         {}
#  1815  srintship  2067         {}
#  1816  srintship  1441         {}
#  1817  srintship  6466         {}
#  1818  srintship  5025         {}
#  1819  srintship  3521         {}
#  1820  srintship  2252         {}
#  1821  srintship  2742         {}
#  1822  srintship  9818         {}
#  1823  srintship  8335         {}
#  1824  srintship  3258         {}
#  1825  srintship  3678         {}
#  1826  srintship  6542         {}
#  1827  srintship  8929         {}
#  1828  srintship  1058         {}
#  1829  srintship  8155         {}
#  1830  srintship  9456         {}
#  1831  srintship  4147         {}
#  1832  srintship  3070         {}
#  1833  srintship  1451         {}
#  1834  srintship  9313         {}
#  1835  srintship  4524         {}
#  1836  srintship  3992         {}
#  1837  srintship  3614         {}
#  1838  srintship  2168         {}
#  1839  srintship  8893         {}
#  1840  srintship  4438         {}
#  1841  srintship  1310         {}
#  1842  srintship  4556         {}
#  1843  srintship  6843         {}
#  1844  srintship  9766         {}
#  1845  srintship  8522         {}
#  1846  srintship  4066         {}
#  1847  srintship  7103         {}
#  1848  srintship  8649         {}
#  1849  srintship  6673         {}
#  1850  srintship  3089         {},
#  'rcextship_nodes':           Label    ID Attributes
#  1851  rcextship  2108         {}
#  1852  rcextship  6720         {}
#  1853  rcextship  5965         {}
#  1854  rcextship  4536         {}
#  1855  rcextship  2575         {}
#  1856  rcextship  1281         {}
#  1857  rcextship  4492         {}
#  1858  rcextship  8644         {}
#  1859  rcextship  6650         {}
#  1860  rcextship  1139         {}
#  1861  rcextship  3142         {}
#  1862  rcextship  8567         {}
#  1863  rcextship  5916         {}
#  1864  rcextship  6604         {}
#  1865  rcextship  8328         {}
#  1866  rcextship  5824         {}
#  1867  rcextship  5924         {}
#  1868  rcextship  2842         {}
#  1869  rcextship  8699         {}
#  1870  rcextship  7945         {}
#  1871  rcextship  4078         {}
#  1872  rcextship  1303         {}
#  1873  rcextship  6590         {}
#  1874  rcextship  3064         {}
#  1875  rcextship  6256         {}
#  1876  rcextship  5806         {}
#  1877  rcextship  8708         {}
#  1878  rcextship  8104         {}
#  1879  rcextship  1123         {}
#  1880  rcextship  1912         {}
#  1881  rcextship  6277         {}
#  1882  rcextship  2823         {}
#  1883  rcextship  2845         {}
#  1884  rcextship  2574         {}
#  1885  rcextship  3496         {}
#  1886  rcextship  7747         {}
#  1887  rcextship  3770         {}
#  1888  rcextship  4965         {}
#  1889  rcextship  4867         {}
#  1890  rcextship  2307         {}
#  1891  rcextship  1248         {}
#  1892  rcextship  9994         {}
#  1893  rcextship  7105         {}
#  1894  rcextship  1331         {}
#  1895  rcextship  5941         {}
#  1896  rcextship  7217         {}
#  1897  rcextship  1410         {}
#  1898  rcextship  1264         {}
#  1899  rcextship  3238         {}
#  1900  rcextship  3852         {}
#  1901  rcextship  8524         {},
#  'scextship_nodes':           Label    ID Attributes
#  1902  scextship  1456         {}
#  1903  scextship  5089         {}
#  1904  scextship  7708         {}
#  1905  scextship  7960         {}
#  1906  scextship  5028         {}
#  1907  scextship  4413         {}
#  1908  scextship  9033         {}
#  1909  scextship  3246         {}
#  1910  scextship  8786         {}
#  1911  scextship  1422         {}
#  1912  scextship  8588         {}
#  1913  scextship  7366         {}
#  1914  scextship  2490         {}
#  1915  scextship  6220         {}
#  1916  scextship  6083         {}
#  1917  scextship  1988         {}
#  1918  scextship  5641         {}
#  1919  scextship  4456         {}
#  1920  scextship  3570         {}
#  1921  scextship  8140         {}
#  1922  scextship  1431         {}
#  1923  scextship  9590         {}
#  1924  scextship  5269         {}
#  1925  scextship  4227         {}
#  1926  scextship  5333         {}
#  1927  scextship  8280         {}
#  1928  scextship  2379         {}
#  1929  scextship  8924         {}
#  1930  scextship  6062         {}
#  1931  scextship  5611         {}
#  1932  scextship  2983         {}
#  1933  scextship  1116         {}
#  1934  scextship  5717         {}
#  1935  scextship  9786         {}
#  1936  scextship  1903         {}
#  1937  scextship  8183         {}
#  1938  scextship  2121         {}
#  1939  scextship  2177         {}
#  1940  scextship  1876         {}
#  1941  scextship  9477         {}
#  1942  scextship  6449         {}
#  1943  scextship  8778         {}
#  1944  scextship  4781         {}
#  1945  scextship  2301         {}
#  1946  scextship  3670         {}
#  1947  scextship  2269         {}
#  1948  scextship  7218         {}
#  1949  scextship  3429         {}
#  1950  scextship  4273         {},
#  'ssintship_nodes':           Label     ID Attributes
#  1951  ssintship   7281         {}
#  1952  ssintship   3477         {}
#  1953  ssintship   8796         {}
#  1954  ssintship   2933         {}
#  1955  ssintship   3000         {}
#  ...         ...    ...        ...
#  2483  ssintship  10478         {}
#  2484  ssintship  10479         {}
#  2485  ssintship  10480         {}
#  2486  ssintship  10481         {}
#  2487  ssintship  10482         {}
#
#  [537 rows x 3 columns],
#  'internalservices_nodes':                  Label    ID  \
#  2488  internalservices  5822
#  2489  internalservices  9032
#  2490  internalservices  6669
#  2491  internalservices  1165
#  2492  internalservices  7448
#  ...                ...   ...
#  2583  internalservices  9334
#  2584  internalservices  5599
#  2585  internalservices  3103
#  2586  internalservices  4859
#  2587  internalservices  5732
#
#                                               Attributes
#  2488  {'placed_when': '1971-03-20', 'actual_date': '...
#  2489  {'placed_when': '1985-07-11', 'actual_date': '...
#  2490  {'placed_when': '1987-07-14', 'actual_date': '...
#  2491  {'placed_when': '2000-08-31', 'actual_date': '...
#  2492  {'placed_when': '1988-01-11', 'actual_date': '...
#  ...                                                 ...
#  2583  {'placed_when': '2017-02-28', 'actual_date': '...
#  2584  {'placed_when': '1973-05-05', 'actual_date': '...
#  2585  {'placed_when': '1988-06-22', 'actual_date': '...
#  2586  {'placed_when': '2000-05-01', 'actual_date': '...
#  2587  {'placed_when': '1997-04-03', 'actual_date': '...
#
#  [100 rows x 3 columns],
#  'rcextorders_nodes':             Label    ID                                         Attributes
#  2588  rcextorders  4444  {'quantity': 222, 'placed_when': '1990-12-23',...
#  2589  rcextorders  8666  {'quantity': 515, 'placed_when': '1979-01-24',...
#  2590  rcextorders  1414  {'quantity': 436, 'placed_when': '1982-04-29',...
#  2591  rcextorders  1321  {'quantity': 308, 'placed_when': '1984-11-12',...
#  2592  rcextorders  5984  {'quantity': 440, 'placed_when': '1982-09-02',...
#  2593  rcextorders  1932  {'quantity': 167, 'placed_when': '2020-09-16',...
#  2594  rcextorders  8691  {'quantity': 522, 'placed_when': '1990-10-31',...
#  2595  rcextorders  7793  {'quantity': 583, 'placed_when': '1972-04-22',...
#  2596  rcextorders  9035  {'quantity': 618, 'placed_when': '1992-10-16',...
#  2597  rcextorders  3622  {'quantity': 136, 'placed_when': '1979-05-10',...
#  2598  rcextorders  7702  {'quantity': 172, 'placed_when': '1987-09-26',...
#  2599  rcextorders  3889  {'quantity': 280, 'placed_when': '1985-08-21',...
#  2600  rcextorders  3158  {'quantity': 978, 'placed_when': '2001-01-08',...
#  2601  rcextorders  4784  {'quantity': 270, 'placed_when': '1977-03-27',...
#  2602  rcextorders  4210  {'quantity': 979, 'placed_when': '1974-12-01',...
#  2603  rcextorders  9638  {'quantity': 224, 'placed_when': '1985-10-09',...
#  2604  rcextorders  4419  {'quantity': 799, 'placed_when': '2015-10-31',...
#  2605  rcextorders  8077  {'quantity': 483, 'placed_when': '2002-03-24',...
#  2606  rcextorders  3828  {'quantity': 967, 'placed_when': '2009-02-14',...
#  2607  rcextorders  2221  {'quantity': 725, 'placed_when': '1975-01-14',...
#  2608  rcextorders  7987  {'quantity': 465, 'placed_when': '2014-03-17',...
#  2609  rcextorders  4759  {'quantity': 699, 'placed_when': '1978-09-17',...
#  2610  rcextorders  2788  {'quantity': 593, 'placed_when': '1987-08-12',...
#  2611  rcextorders  9746  {'quantity': 342, 'placed_when': '1996-02-19',...
#  2612  rcextorders  3779  {'quantity': 961, 'placed_when': '1976-06-29',...
#  2613  rcextorders  7437  {'quantity': 789, 'placed_when': '1992-05-22',...
#  2614  rcextorders  4500  {'quantity': 343, 'placed_when': '2006-02-11',...
#  2615  rcextorders  1617  {'quantity': 650, 'placed_when': '1993-05-31',...
#  2616  rcextorders  1919  {'quantity': 689, 'placed_when': '2000-04-29',...
#  2617  rcextorders  6510  {'quantity': 486, 'placed_when': '2010-09-09',...
#  2618  rcextorders  4244  {'quantity': 141, 'placed_when': '1970-12-08',...
#  2619  rcextorders  3497  {'quantity': 372, 'placed_when': '1977-07-28',...
#  2620  rcextorders  9300  {'quantity': 496, 'placed_when': '1993-02-17',...
#  2621  rcextorders  7466  {'quantity': 261, 'placed_when': '1993-04-14',...
#  2622  rcextorders  5302  {'quantity': 975, 'placed_when': '1976-10-30',...
#  2623  rcextorders  5763  {'quantity': 257, 'placed_when': '2021-10-21',...
#  2624  rcextorders  4469  {'quantity': 297, 'placed_when': '1979-02-20',...
#  2625  rcextorders  4563  {'quantity': 634, 'placed_when': '1977-12-01',...
#  2626  rcextorders  2997  {'quantity': 473, 'placed_when': '2021-07-29',...
#  2627  rcextorders  1129  {'quantity': 524, 'placed_when': '2010-02-18',...
#  2628  rcextorders  5489  {'quantity': 816, 'placed_when': '1992-07-02',...
#  2629  rcextorders  7534  {'quantity': 619, 'placed_when': '2010-01-11',...
#  2630  rcextorders  9113  {'quantity': 205, 'placed_when': '1978-01-30',...
#  2631  rcextorders  7630  {'quantity': 360, 'placed_when': '1995-08-10',...
#  2632  rcextorders  9271  {'quantity': 521, 'placed_when': '2016-10-12',...
#  2633  rcextorders  8183  {'quantity': 292, 'placed_when': '1998-09-28',...
#  2634  rcextorders  2531  {'quantity': 578, 'placed_when': '2015-06-28',...
#  2635  rcextorders  5348  {'quantity': 248, 'placed_when': '2002-08-30',...
#  2636  rcextorders  3080  {'quantity': 393, 'placed_when': '2000-07-18',...
#  2637  rcextorders  6047  {'quantity': 221, 'placed_when': '1998-10-30',...
#  2638  rcextorders  6474  {'quantity': 937, 'placed_when': '1972-12-26',...
#  2639  rcextorders  1154  {'quantity': 820, 'placed_when': '1974-01-24',...,
#  'facilities_nodes':            Label      ID                                         Attributes
#  2640  facilities  694420  {'market_cap': '166    1.265555e+10\r\nName: m...
#  2641  facilities  678955  {'market_cap': '166    2.036310e+10\r\nName: m...
#  2642  facilities  719035  {'market_cap': '166    2.420775e+10\r\nName: m...
#  2643  facilities  240432  {'market_cap': '166    2.079319e+09\r\nName: m...
#  2644  facilities  385384  {'market_cap': '166    8.591279e+10\r\nName: m...
#  ...          ...     ...                                                ...
#  4635  facilities  458827  {'market_cap': '120    9.000936e+10\r\nName: m...
#  4636  facilities  953728  {'market_cap': '120    2.039393e+11\r\nName: m...
#  4637  facilities  902028  {'market_cap': '120    2.810986e+10\r\nName: m...
#  4638  facilities  143381  {'market_cap': '120    1.147001e+10\r\nName: m...
#  4639  facilities  186890  {'market_cap': '120    5.587409e+10\r\nName: m...
#
#  [2000 rows x 3 columns],
#  'externalservices_nodes':                  Label    ID  \
#  4640  externalservices  8478
#  4641  externalservices  9860
#  4642  externalservices  1567
#  4643  externalservices  5121
#  4644  externalservices  4942
#  ...                ...   ...
#  4735  externalservices  2021
#  4736  externalservices  9783
#  4737  externalservices  1044
#  4738  externalservices  3024
#  4739  externalservices  3006
#
#                                               Attributes
#  4640  {'placed_when': '1970-01-21', 'actual_date': '...
#  4641  {'placed_when': '1971-09-10', 'actual_date': '...
#  4642  {'placed_when': '2001-10-02', 'actual_date': '...
#  4643  {'placed_when': '2004-01-30', 'actual_date': '...
#  4644  {'placed_when': '1970-09-08', 'actual_date': '...
#  ...                                                 ...
#  4735  {'placed_when': '1987-03-28', 'actual_date': '...
#  4736  {'placed_when': '2005-08-23', 'actual_date': '...
#  4737  {'placed_when': '2018-10-09', 'actual_date': '...
#  4738  {'placed_when': '2013-06-22', 'actual_date': '...
#  4739  {'placed_when': '2017-07-16', 'actual_date': '...
#
#  [100 rows x 3 columns],
#  'products_nodes':          Label   ID                                         Attributes
#  4740  products  911  {'product_type': 'M', 'product_name': 'WWW', '...
#  4741  products  316  {'product_type': 'F', 'product_name': 'MMM', '...
#  4742  products  549  {'product_type': 'P', 'product_name': 'LLL', '...
#  4743  products  801  {'product_type': 'V', 'product_name': 'SSS', '...
#  4744  products  791  {'product_type': 'R', 'product_name': 'AAA', '...
#  ...        ...  ...                                                ...
#  5235  products  835  {'product_type': 'D', 'product_name': 'KKK', '...
#  5236  products  323  {'product_type': 'C', 'product_name': 'III', '...
#  5237  products  742  {'product_type': 'M', 'product_name': 'OOO', '...
#  5238  products  412  {'product_type': 'X', 'product_name': 'III', '...
#  5239  products  711  {'product_type': 'X', 'product_name': 'MMM', '...
#
#  [500 rows x 3 columns],
#  'srintorders_nodes':             Label    ID                                         Attributes
#  5240  srintorders  8605  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5241  srintorders  3057  {'quantity': 771, 'placed_when': '2007-10-29',...
#  5242  srintorders  7340  {'quantity': 870, 'placed_when': '2000-07-24',...
#  5243  srintorders  1532  {'quantity': 127, 'placed_when': '2009-06-07',...
#  5244  srintorders  2409  {'quantity': 560, 'placed_when': '2017-06-07',...
#  ...           ...   ...                                                ...
#  5309  srintorders  9959  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5310  srintorders  9960  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5311  srintorders  9961  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5312  srintorders  9963  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5313  srintorders  9964  {'quantity': 766, 'placed_when': '1993-05-08',...
#
#  [74 rows x 3 columns],
#  'scextorders_nodes':             Label    ID                                         Attributes
#  5314  scextorders  9052  {'quantity': 217, 'placed_when': '1980-08-10',...
#  5315  scextorders  5139  {'quantity': 284, 'placed_when': '2008-07-27',...
#  5316  scextorders  8454  {'quantity': 409, 'placed_when': '2010-07-09',...
#  5317  scextorders  4453  {'quantity': 948, 'placed_when': '1977-02-05',...
#  5318  scextorders  5311  {'quantity': 983, 'placed_when': '2003-10-31',...
#  5319  scextorders  5650  {'quantity': 268, 'placed_when': '1978-09-22',...
#  5320  scextorders  4806  {'quantity': 546, 'placed_when': '1993-06-18',...
#  5321  scextorders  6681  {'quantity': 730, 'placed_when': '1981-10-31',...
#  5322  scextorders  4718  {'quantity': 692, 'placed_when': '1991-02-21',...
#  5323  scextorders  4479  {'quantity': 493, 'placed_when': '1992-10-10',...
#  5324  scextorders  5183  {'quantity': 583, 'placed_when': '2013-06-28',...
#  5325  scextorders  4926  {'quantity': 600, 'placed_when': '1986-04-26',...
#  5326  scextorders  9507  {'quantity': 509, 'placed_when': '1989-08-12',...
#  5327  scextorders  3871  {'quantity': 186, 'placed_when': '1980-04-08',...
#  5328  scextorders  8782  {'quantity': 578, 'placed_when': '2020-04-22',...
#  5329  scextorders  2718  {'quantity': 789, 'placed_when': '1989-10-20',...
#  5330  scextorders  1738  {'quantity': 988, 'placed_when': '1983-03-18',...
#  5331  scextorders  8174  {'quantity': 886, 'placed_when': '1970-11-12',...
#  5332  scextorders  3104  {'quantity': 438, 'placed_when': '1992-03-04',...
#  5333  scextorders  6786  {'quantity': 308, 'placed_when': '1977-02-12',...
#  5334  scextorders  4823  {'quantity': 145, 'placed_when': '1973-11-05',...
#  5335  scextorders  7762  {'quantity': 954, 'placed_when': '2001-02-28',...
#  5336  scextorders  6448  {'quantity': 989, 'placed_when': '1971-07-12',...
#  5337  scextorders  7889  {'quantity': 509, 'placed_when': '1992-05-25',...
#  5338  scextorders  2563  {'quantity': 869, 'placed_when': '1993-07-27',...
#  5339  scextorders  9772  {'quantity': 772, 'placed_when': '2021-01-08',...
#  5340  scextorders  1848  {'quantity': 815, 'placed_when': '2019-12-07',...
#  5341  scextorders  4730  {'quantity': 471, 'placed_when': '2008-12-05',...
#  5342  scextorders  7545  {'quantity': 158, 'placed_when': '1996-06-23',...
#  5343  scextorders  2232  {'quantity': 372, 'placed_when': '2012-09-07',...
#  5344  scextorders  6722  {'quantity': 838, 'placed_when': '2001-09-29',...
#  5345  scextorders  3115  {'quantity': 153, 'placed_when': '1996-02-26',...
#  5346  scextorders  5531  {'quantity': 448, 'placed_when': '1999-01-01',...
#  5347  scextorders  2261  {'quantity': 225, 'placed_when': '1981-06-14',...
#  5348  scextorders  5443  {'quantity': 321, 'placed_when': '1972-07-31',...
#  5349  scextorders  9064  {'quantity': 295, 'placed_when': '1983-12-09',...
#  5350  scextorders  6082  {'quantity': 994, 'placed_when': '2006-04-15',...
#  5351  scextorders  3801  {'quantity': 574, 'placed_when': '2020-03-08',...
#  5352  scextorders  5957  {'quantity': 371, 'placed_when': '2015-09-27',...
#  5353  scextorders  1798  {'quantity': 758, 'placed_when': '1970-10-26',...
#  5354  scextorders  5688  {'quantity': 349, 'placed_when': '1988-12-02',...
#  5355  scextorders  3805  {'quantity': 810, 'placed_when': '2006-06-27',...
#  5356  scextorders  5109  {'quantity': 745, 'placed_when': '1973-09-14',...
#  5357  scextorders  7571  {'quantity': 494, 'placed_when': '1980-04-28',...
#  5358  scextorders  4710  {'quantity': 349, 'placed_when': '1980-04-07',...
#  5359  scextorders  7112  {'quantity': 688, 'placed_when': '2006-03-19',...
#  5360  scextorders  8940  {'quantity': 706, 'placed_when': '2002-01-30',...
#  5361  scextorders  9561  {'quantity': 980, 'placed_when': '2014-02-21',...,
#  'ssintorders_nodes':             Label     ID                                         Attributes
#  5362  ssintorders   6266  {'quantity': 438, 'placed_when': '1975-01-08',...
#  5363  ssintorders   5318  {'quantity': 801, 'placed_when': '2021-01-18',...
#  5364  ssintorders   2439  {'quantity': 882, 'placed_when': '1978-07-09',...
#  5365  ssintorders   1851  {'quantity': 220, 'placed_when': '2002-12-28',...
#  5366  ssintorders   9800  {'quantity': 399, 'placed_when': '1975-10-06',...
#  ...           ...    ...                                                ...
#  5905  ssintorders  10448  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5906  ssintorders  10449  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5907  ssintorders  10450  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5908  ssintorders  10451  {'quantity': 766, 'placed_when': '1993-05-08',...
#  5909  ssintorders  10452  {'quantity': 766, 'placed_when': '1993-05-08',...
#
#  [548 rows x 3 columns]}

# %% [markdown]
# ## Expanding Attributes column

# %%
All_dfs["supplier"]
# Out:
#      supp_id            supplier_name                           country  \
# 0      34258               Taylor PLC  Lao People's Democratic Republic
# 1      40868           Sorrentino SPA                        Mozambique
# 2      27813          Persico e figli        Saint Martin (French part)
# 3      57551            Karge OHG mbH                 Brunei Darussalam
# 4      50099  Smith, Porter and Lynch                             Palau
# ..       ...                      ...                               ...
# 295    90256                  Förster                          Ethiopia
# 296    35266       Gotthard Zahn GmbH                           Finland
# 297    52647                Cook-Webb                           Morocco
# 298    13355                Shah-Lowe          Central African Republic
# 299    48467               Brandt Ltd                          Anguilla
#
#              city_name currency                                type  \
# 0            Viangchan  Dollars                  Financial Services
# 1                 Gaza  Dollars                         Real Estate
# 2              Unknown  Dollars  Paper, Forest Products & Packaging
# 3               Belait  Dollars                           Oil & Gas
# 4             Ngatpang  Dollars               Automotive & Assembly
# ..                 ...      ...                                 ...
# 295        Addis Ababa  Dollars  Paper, Forest Products & Packaging
# 296          Pohjanmaa  Dollars       Healthcare Systems & Services
# 297            Berkane  Dollars  Paper, Forest Products & Packaging
# 298  Bamingui-Bangoran  Dollars               Automotive & Assembly
# 299            Unknown  Dollars                           Oil & Gas
#
#      number_of_employees  Annual_sales  number_of_orders  market_share (%)  \
# 0                    446        465.22              5565                48
# 1                    533       8881.74              1871                98
# 2                    578         58.99              8611                 9
# 3                    145          3.35              4320                41
# 4                    872          8.39              2090                78
# ..                   ...           ...               ...               ...
# 295                  764       7024.13              7003                46
# 296                  570          6.51              7985                42
# 297                  762         10.69              2171                35
# 298                  862         37.45              6844                50
# 299                  593        788.49              1593                20
#
#      market_capitalization ($)
# 0                 5.970000e+11
# 1                 9.170000e+11
# 2                 6.980000e+11
# 3                 8.790000e+11
# 4                 6.050000e+11
# ..                         ...
# 295               6.919014e+10
# 296               1.470000e+11
# 297               7.630000e+11
# 298               2.150000e+11
# 299               3.250000e+11
#
# [300 rows x 11 columns]

# %%
mynodes.Label.unique()
# Out:
# array(['supplier', 'retailer', 'customer', 'warehouses',
#        'externaltransactions', 'internaltransactions', 'srintship',
#        'rcextship', 'scextship', 'ssintship', 'internalservices',
#        'rcextorders', 'facilities', 'externalservices', 'products',
#        'srintorders', 'scextorders', 'ssintorders'], dtype=object)

# %% [markdown]
# ## Separating each node according to its Label

# %%
from IPython.display import display, HTML

train_data=dict()

# for key in list(set(list(All_dfs)) & set(mynodes.Label.unique())):
for key in mynodes.Label.unique():
    current_node=all_nodes[f"{key}_nodes"]
    current_node=current_node.drop(columns=["Attributes"])
    train_data[key]=pd.merge(All_dfs[key], current_node, left_on=list(All_dfs[key])[0], right_on='ID')
    # ids=list(filter(lambda x: "id" in x.lower(), list(train_data[key])))+["Label"]
    # print(ids)
    # train_data[key]=train_data[key].drop(columns=ids)

# for key, node in train_data.items():
#     print(key)
#     display(node)

# %% [markdown]
# ## Testing KMeans Clustering model on sample node (customer_node)
# ### - We test using customer node assuming that this is the final node of the supply chain path

# %%
# sns.scatterplot(x='Gene One',y='Gene Two',hue='Cancer Present',data=df,alpha=0.7)
customer_node=(pd.DataFrame( train_data["customer"]))
customer_node.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cust_id          150 non-null    int64
#  1   gender           150 non-null    object
#  2   first_name       150 non-null    object
#  3   last_name        150 non-null    object
#  4   country          150 non-null    object
#  5   nationality      150 non-null    object
#  6   profession       150 non-null    object
#  7   marital_status   150 non-null    object
#  8   education_level  150 non-null    object
#  9   age              150 non-null    int64
#  10  Label            150 non-null    object
#  11  ID               150 non-null    int64
# dtypes: int64(3), object(9)
# memory usage: 15.2+ KB

# %%
plt.figure(figsize=(12,6),dpi=200)
sns.histplot(data=customer_node,x='age',hue="gender")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ## Preprocessing data

# %%
from sklearn.preprocessing import OneHotEncoder


ids=list(filter(lambda x: "id" in x.lower(), customer_node.columns))+["Label"]

# X=customer_node.loc[customer_node.columns != ids]
X = customer_node[customer_node.columns.difference(ids)]
# define one hot encoding

encoder = OneHotEncoder(handle_unknown="ignore")
# transform data
onehot = encoder.fit_transform(X)

# Apply the encoder.
X_train = encoder.transform(X)
# sns.scatterplot(x='Gene One',y='Gene Two',hue='Cancer Present',data=df,alpha=0.7)
plt.spy(X_train,markersize=0.7)
# sns.pairplot()
# scaled_X = scaler.fit_transform(X)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean=False)
scaled_X = scaler.fit_transform(X_train)

# %%
from sklearn.cluster import KMeans

ssd = []

for k in range(3,40):
    
    model = KMeans(n_clusters=k)
    
    
    model.fit(scaled_X)
    
    #Sum of squared distances of samples to their closest cluster center.
    ssd.append(model.inertia_)

# %%
plt.plot(range(3,40),ssd,'o--')
plt.xlabel("K Value")
plt.ylabel(" Sum of Squared Distances")
# Out:
# Text(0, 0.5, ' Sum of Squared Distances')

# %% [markdown]
# ## Choosing k=32

# %%
ssd
# Out:
# [99832.37573114307,
#  99113.93711652633,
#  98218.66947381297,
#  97426.97439477847,
#  96656.66526861642,
#  95690.77643499053,
#  95046.35514129222,
#  94262.74506910829,
#  93263.95128299962,
#  92709.28094640066,
#  91778.97269797721,
#  91026.6845984149,
#  90343.0899581495,
#  89570.25909026206,
#  88777.17725534482,
#  87810.91810463212,
#  86904.28067132214,
#  86222.22867191203,
#  85435.5744938351,
#  84640.11213432546,
#  83914.18640848198,
#  82974.40823569517,
#  82222.96106525892,
#  81337.45297535286,
#  80521.61882805708,
#  79464.15916650312,
#  78803.19927886807,
#  78262.08891828843,
#  77250.16647643021,
#  76581.67252913237,
#  75923.48569622631,
#  74955.47989713814,
#  74186.96142563215,
#  73288.38261408766,
#  72618.82181901253,
#  71853.89179154398,
#  71043.03052408021]

# %%
# Change in SSD from previous K value!
pd.Series(ssd).diff()
# Out:
# 0             NaN
# 1     -718.438615
# 2     -895.267643
# 3     -791.695079
# 4     -770.309126
# 5     -965.888834
# 6     -644.421294
# 7     -783.610072
# 8     -998.793786
# 9     -554.670337
# 10    -930.308248
# 11    -752.288100
# 12    -683.594640
# 13    -772.830868
# 14    -793.081835
# 15    -966.259151
# 16    -906.637433
# 17    -682.051999
# 18    -786.654178
# 19    -795.462360
# 20    -725.925726
# 21    -939.778173
# 22    -751.447170
# 23    -885.508090
# 24    -815.834147
# 25   -1057.459662
# 26    -660.959888
# 27    -541.110361
# 28   -1011.922442
# 29    -668.493947
# 30    -658.186833
# 31    -968.005799
# 32    -768.518472
# 33    -898.578812
# 34    -669.560795
# 35    -764.930027
# 36    -810.861267
# dtype: float64

# %%
pd.Series(ssd).diff().plot(kind='bar')
# Out:
# <Axes: >

# %%
list(customer_node.select_dtypes(include=["object"]))
# Out:
# ['gender',
#  'first_name',
#  'last_name',
#  'country',
#  'nationality',
#  'profession',
#  'marital_status',
#  'education_level',
#  'Label']

# %% [markdown]
# ## Clustering on all Nodes
#
# just adjust the code for when to scale or not & when to encode or not some cases u will not need both at the same times

# %%
k=32
ssd_nodes=[]
labels_nodes=[]
type_map = {str: 'string', tuple: 'tuple', list: 'list', dict: 'dict', int: 'int' ,float: "float"}

for node_name,node_value in train_data.items():
    unique_values={}
    c_node=train_data[node_name]
    
    cols2rm=[]
    
    # determine the data type of each element
    for t in list(c_node):
        c_node[f'{t}_type'] = c_node[t].map(type).map(type_map).fillna('other')
        if(len(c_node[f'{t}_type'].unique().tolist()))==1:
            if( (c_node[f'{t}_type'].unique().tolist())[0] not in ['string','int','float']):
                cols2rm.append(t)
        c_node=c_node.drop(columns=[f'{t}_type'], axis=1)
    
    
    
    print(f"Node name: {node_name}")
    print(f"Node shape (rows,columns): {node_value.shape}")
    print(f"Node dtypes: {c_node.dtypes}")
    print(f"Node specifc dtypes: {unique_values}")
    print(f"Columns to remove: {cols2rm}")
    ids=list(filter(lambda x: "id" in x.lower(), c_node.columns))+["Label"]+cols2rm
    
    print("Ignoring id columns +others...")
    print(ids)

    X = c_node[c_node.columns.difference(ids)]
    
    # display(X)

    if len(list(X.select_dtypes(exclude=["object"]))) != 0:

        print("Scaling....")
        # print("X before scaling: ")
        # display(X)
        
        # create the StandardScaler object
        scaler = StandardScaler()

        # fit and transform the data
        df_scaled = scaler.fit_transform(X[list(X.select_dtypes(exclude=["object"]))])
        
        # create a dataframe with the scaled features
        df_scaled = pd.DataFrame(df_scaled, columns=list(X.select_dtypes(exclude=["object"])))
        
        X=X.drop(list(X.select_dtypes(exclude=["object"])), axis=1)
        X = pd.concat([X, df_scaled], axis=1)
        # print("X after scaling:")
        # display(X)
    
    # define one hot encoding
    
    if len(list(X.select_dtypes(include=["object"]))) != 0:
        
        print("Encoding....")
        
        # print("X before encoding:")
        # display(X)
    
        ohe = OneHotEncoder()

        # fit and transform the data
        # display(X[list(X.select_dtypes(include=["object"]))])
        Xn = ohe.fit_transform(X[list(X.select_dtypes(include=["object"]))]).toarray()

        # get the feature names generated by the encoder
        feature_names = ohe.get_feature_names(list(X.select_dtypes(include=["object"])))

        # create a dataframe with the encoded features
        df_encoded = pd.DataFrame(Xn, columns=feature_names)
        
        # drop the original column
        X =  X.drop(list(X.select_dtypes(include=["object"])), axis=1)

        # concatenate the original data with the encoded features
        X = pd.concat([X, df_encoded], axis=1)

        
        # In this example, the OneHotEncoder object is created and fit to the data using the fit_transform method.
        # The result of the transformation is stored in the X array. 
        # The get_feature_names method is then used to get the names of the new columns created by the encoder. 
        # These names are used to create a dataframe with the encoded features.
        # Finally, the original data is concatenated with the encoded data and the original column is dropped to produce the final dataframe.
        
        # print("X after encoding:")
        # display(X)

    # break
    
    # break
    
    print("Model Fitting....")
    model = KMeans(n_clusters=k)
    
    model.fit(X)
    print("Prediction Fitting...")
    cluster_labels = model.fit_predict(X)
    
    ssd_nodes.append(model.inertia_)
    labels_nodes.append(cluster_labels)
    
    # c_node['Cluster']=cluster_labels
    train_data[node_name]['Cluster']=cluster_labels
    print("Node with cluster coulmn:")
    display(train_data[node_name])
    # break
    
    print("\n")
    # sns.scatterplot(x='Gene One',y='Gene Two',hue='Cancer Present',data=df,alpha=0.7)
    
    # sns.pairplot()
# Out:
# Node name: supplier
# Node shape (rows,columns): (300, 14)
# Node dtypes: supp_id                        int64
# supplier_name                 object
# country                       object
# city_name                     object
# currency                      object
# type                          object
# number_of_employees            int64
# Annual_sales                 float64
# number_of_orders               int64
# market_share (%)               int64
# market_capitalization ($)    float64
# Label                         object
# ID                             int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['supp_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#      supp_id            supplier_name                           country  \
# 0      34258               Taylor PLC  Lao People's Democratic Republic
# 1      40868           Sorrentino SPA                        Mozambique
# 2      27813          Persico e figli        Saint Martin (French part)
# 3      57551            Karge OHG mbH                 Brunei Darussalam
# 4      50099  Smith, Porter and Lynch                             Palau
# ..       ...                      ...                               ...
# 295    90256                  Förster                          Ethiopia
# 296    35266       Gotthard Zahn GmbH                           Finland
# 297    52647                Cook-Webb                           Morocco
# 298    13355                Shah-Lowe          Central African Republic
# 299    48467               Brandt Ltd                          Anguilla
#
#              city_name currency                                type  \
# 0            Viangchan  Dollars                  Financial Services
# 1                 Gaza  Dollars                         Real Estate
# 2              Unknown  Dollars  Paper, Forest Products & Packaging
# 3               Belait  Dollars                           Oil & Gas
# 4             Ngatpang  Dollars               Automotive & Assembly
# ..                 ...      ...                                 ...
# 295        Addis Ababa  Dollars  Paper, Forest Products & Packaging
# 296          Pohjanmaa  Dollars       Healthcare Systems & Services
# 297            Berkane  Dollars  Paper, Forest Products & Packaging
# 298  Bamingui-Bangoran  Dollars               Automotive & Assembly
# 299            Unknown  Dollars                           Oil & Gas
#
#      number_of_employees  Annual_sales  number_of_orders  market_share (%)  \
# 0                    446        465.22              5565                48
# 1                    533       8881.74              1871                98
# 2                    578         58.99              8611                 9
# 3                    145          3.35              4320                41
# 4                    872          8.39              2090                78
# ..                   ...           ...               ...               ...
# 295                  764       7024.13              7003                46
# 296                  570          6.51              7985                42
# 297                  762         10.69              2171                35
# 298                  862         37.45              6844                50
# 299                  593        788.49              1593                20
#
#      market_capitalization ($)     Label     ID supp_id_type  Cluster
# 0                 5.970000e+11  supplier  34258          int        1
# 1                 9.170000e+11  supplier  40868          int       15
# 2                 6.980000e+11  supplier  27813          int       29
# 3                 8.790000e+11  supplier  57551          int       19
# 4                 6.050000e+11  supplier  50099          int        0
# ..                         ...       ...    ...          ...      ...
# 295               6.919014e+10  supplier  90256          int        2
# 296               1.470000e+11  supplier  35266          int       18
# 297               7.630000e+11  supplier  52647          int        8
# 298               2.150000e+11  supplier  13355          int        5
# 299               3.250000e+11  supplier  48467          int       24
#
# [300 rows x 15 columns]
# Node name: retailer
# Node shape (rows,columns): (150, 13)
# Node dtypes: retailer_id          int64
# country             object
# city_name           object
# type                object
# reviews_number       int64
# retailer_types      object
# rating               int64
# opening_hours        int64
# capacity (units)     int64
# products_sold       object
# Label               object
# ID                   int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: ['retailer_types', 'products_sold']
# Ignoring id columns +others...
# ['retailer_id', 'ID', 'Label', 'retailer_types', 'products_sold']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#      retailer_id                           country            city_name  \
# 0          91089                           Tunisia             Kairouan
# 1          95444                            Kuwait        Al Farwānīyah
# 2          66051                             Qatar       Ash Shīḩānīyah
# 3          41072                            Greece     Dytikí Makedonía
# 4          34083                            Gambia               Banjul
# ..           ...                               ...                  ...
# 145        86308                           Ukraine  Chernihivska oblast
# 146        18464                             Haiti             Grandans
# 147        57039  Lao People's Democratic Republic            Viangchan
# 148        33250                       South Sudan                Lakes
# 149        21789                            Cyprus          Ammochostos
#
#              type  reviews_number                   retailer_types  rating  \
# 0     distributer             650                               []       5
# 1          vendor             441                               []       1
# 2          abroad             821                               []       2
# 3    customer end             123  [Healthcare Systems & Services]       2
# 4          vendor             815                               []       4
# ..            ...             ...                              ...     ...
# 145        vendor             987             [Financial Services]       4
# 146  customer end             295                               []       2
# 147        vendor             450                               []       2
# 148  customer end             318                               []       4
# 149   distributer             907                               []       3
#
#      opening_hours  capacity (units) products_sold     Label     ID  \
# 0                7            169554            []  retailer  91089
# 1                8            325442            []  retailer  95444
# 2                9            426160            []  retailer  66051
# 3                4           1347204    [558, 839]  retailer  41072
# 4                7           1843949            []  retailer  34083
# ..             ...               ...           ...       ...    ...
# 145              8           1316087         [772]  retailer  86308
# 146              5           1686073            []  retailer  18464
# 147              7           1019346            []  retailer  57039
# 148              6            716050            []  retailer  33250
# 149              5            284423            []  retailer  21789
#
#     retailer_id_type  Cluster
# 0                int       26
# 1                int       18
# 2                int       10
# 3                int       30
# 4                int       22
# ..               ...      ...
# 145              int       22
# 146              int       30
# 147              int        9
# 148              int       23
# 149              int       10
#
# [150 rows x 14 columns]
# Node name: customer
# Node shape (rows,columns): (150, 13)
# Node dtypes: cust_id             int64
# gender             object
# first_name         object
# last_name          object
# country            object
# nationality        object
# profession         object
# marital_status     object
# education_level    object
# age                 int64
# Label              object
# ID                  int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['cust_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#      cust_id gender first_name  last_name                  country  \
# 0      33736      F      Nadia     Scheel               Cabo Verde
# 1      42959      M       Eric      David                 Dominica
# 2      50653      F    Alessia   Villegas  Virgin Islands, British
# 3      82485      M     Alexei       Wulf                    Samoa
# 4      56609      F     Brenda        Fox                   Poland
# ..       ...    ...        ...        ...                      ...
# 145    82421      F       Mary       Bell               Montserrat
# 146    14074      F       Luce    Le Gall                   Jersey
# 147    95571      M    Timothy     Moreno               Madagascar
# 148    41209      F       Emmi    Fritsch                 Colombia
# 149    47008      F     Lauren  Toscanini            Liechtenstein
#
#                  nationality  \
# 0                 Cabo Verde
# 1                      Italy
# 2    Virgin Islands, British
# 3                      Samoa
# 4                     Poland
# ..                       ...
# 145                    Italy
# 146                   Jersey
# 147               Madagascar
# 148                  Germany
# 149            United States
#
#                                             profession marital_status  \
# 0                     Production assistant, television         Single
# 1    Scientist, clinical (histocompatibility and im...        Married
# 2                                    directeur de golf       Divorced
# 3                              Scientist, audiological       Divorced
# 4                                             actuaire          Widow
# ..                                                 ...            ...
# 145                                   Network engineer          Widow
# 146                                    Games developer         Single
# 147                       Engineer, civil (consulting)         Single
# 148  ingénieur fluides, énergies, réseaux, environn...          Widow
# 149                    Sport and exercise psychologist       Divorced
#
#      education_level  age     Label     ID cust_id_type  Cluster
# 0         PHD holder   92  customer  33736          int       13
# 1         PHD holder   39  customer  42959          int       23
# 2         PHD holder   43  customer  50653          int       18
# 3    Bachelor holder   54  customer  82485          int        1
# 4    Bachelor holder   83  customer  56609          int       14
# ..               ...  ...       ...    ...          ...      ...
# 145  Bachelor holder   42  customer  82421          int       16
# 146   Masters holder   26  customer  14074          int        7
# 147   Masters holder   74  customer  95571          int        3
# 148      High school   64  customer  41209          int        4
# 149   Masters holder   37  customer  47008          int        0
#
# [150 rows x 14 columns]
# Node name: warehouses
# Node shape (rows,columns): (1000, 10)
# Node dtypes: warehouse_id             int64
# country                 object
# city_name               object
# capacity (NA)            int64
# product_types           object
# Operations Expenses    float64
# Rental price           float64
# Label                   object
# ID                       int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: ['product_types']
# Ignoring id columns +others...
# ['warehouse_id', 'ID', 'Label', 'product_types']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#      warehouse_id                           country  \
# 0            1012                      Sierra Leone
# 1            1017                           Réunion
# 2            1028                            Malawi
# 3            1034  Lao People's Democratic Republic
# 4            1045           Cocos (Keeling) Islands
# ..            ...                               ...
# 995          9964                            Norway
# 996          9970                     Bouvet Island
# 997          9975    Plurinational State of Bolivia
# 998          9981                             Qatar
# 999          9996                           Tunisia
#
#                      city_name  capacity (NA)          product_types  \
# 0                      Eastern         870268           [B, N, D, R]
# 1                      Unknown         453753           [G, W, O, A]
# 2                      Chitipa         687914  [Z, M, F, E, O, X, S]
# 3                    Viangchan         594912  [H, D, R, G, O, A, W]
# 4                      Unknown         336363           [S, Q, C, V]
# ..                         ...            ...                    ...
# 995  Jan Mayen (Arctic Region)         918141           [U, T, H, L]
# 996                    Unknown         654580                 [B, W]
# 997                     Tarija         850849  [I, K, W, A, V, Y, Z]
# 998                 Ash Shamāl         105036                 [Q, A]
# 999                  Ben Arous         741178           [M, N, U, L]
#
#      Operations Expenses  Rental price       Label    ID warehouse_id_type  \
# 0                   0.51          2.87  warehouses  1012               int
# 1                   0.67          2.11  warehouses  1017               int
# 2                   0.59          2.26  warehouses  1028               int
# 3                   0.93          2.70  warehouses  1034               int
# 4                   0.67          1.93  warehouses  1045               int
# ..                   ...           ...         ...   ...               ...
# 995                 0.66          1.88  warehouses  9964               int
# 996                 0.74          1.91  warehouses  9970               int
# 997                 0.54          2.13  warehouses  9975               int
# 998                 0.70          2.91  warehouses  9981               int
# 999                 0.70          2.49  warehouses  9996               int
#
#      Cluster
# 0         12
# 1         21
# 2          6
# 3         15
# 4         21
# ..       ...
# 995       11
# 996       21
# 997       13
# 998       30
# 999       25
#
# [1000 rows x 11 columns]
# Node name: externaltransactions
# Node shape (rows,columns): (100, 6)
# Node dtypes: ExtTran_id     int64
# CompFrom       int64
# Custto         int64
# Label         object
# ID             int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['ExtTran_id', 'ID', 'Label']
# Scaling....
# Model Fitting....
# Prediction Fitting...
# Node with cluster coulmn:
#     ExtTran_id  CompFrom  Custto                 Label    ID ExtTran_id_type  \
# 0         2611     74318   13248  externaltransactions  2611             int
# 1         7858     90236   99404  externaltransactions  7858             int
# 2         4247     19878   50653  externaltransactions  4247             int
# 3         2530     91465   50014  externaltransactions  2530             int
# 4         3381     54148   87421  externaltransactions  3381             int
# ..         ...       ...     ...                   ...   ...             ...
# 95        9232     87695   11082  externaltransactions  9232             int
# 96        8429     13920   41538  externaltransactions  8429             int
# 97        4926     23640   78934  externaltransactions  4926             int
# 98        6209     35841   18779  externaltransactions  6209             int
# 99        8719     87695   32819  externaltransactions  8719             int
#
#     Cluster
# 0        16
# 1        29
# 2        22
# 3         7
# 4        19
# ..      ...
# 95       11
# 96       22
# 97       30
# 98       20
# 99       24
#
# [100 rows x 7 columns]
# Node name: internaltransactions
# Node shape (rows,columns): (100, 6)
# Node dtypes: IntTran_id     int64
# CompFrom       int64
# Compto         int64
# Label         object
# ID             int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['IntTran_id', 'ID', 'Label']
# Scaling....
# Model Fitting....
# Prediction Fitting...
# Node with cluster coulmn:
#     IntTran_id  CompFrom  Compto                 Label    ID IntTran_id_type  \
# 0         7927     78265   87916  internaltransactions  7927             int
# 1         8659     56104   30864  internaltransactions  8659             int
# 2         2751     34967   57109  internaltransactions  2751             int
# 3         3389     52082   87695  internaltransactions  3389             int
# 4         3917     92698   16265  internaltransactions  3917             int
# ..         ...       ...     ...                   ...   ...             ...
# 95        9055     58976   46204  internaltransactions  9055             int
# 96        8775     40597   71916  internaltransactions  8775             int
# 97        8685     28042   70050  internaltransactions  8685             int
# 98        5939     19878   55787  internaltransactions  5939             int
# 99        9269     19072   57109  internaltransactions  9269             int
#
#     Cluster
# 0         7
# 1        28
# 2        24
# 3        12
# 4        25
# ..      ...
# 95       30
# 96        1
# 97       15
# 98        8
# 99        8
#
# [100 rows x 7 columns]
# Node name: srintship
# Node shape (rows,columns): (51, 7)
# Node dtypes: IntShip_id             int64
# listSuppIds            int64
# factoryIds             int64
# TransportationType    object
# Label                 object
# ID                     int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['IntShip_id', 'listSuppIds', 'factoryIds', 'ID', 'Label']
# Encoding....
# Model Fitting....
# Prediction Fitting...
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17452\2502252675.py:100: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   model.fit(X)
# Node with cluster coulmn:
# d:\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1255: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
#     IntShip_id  listSuppIds  factoryIds TransportationType      Label    ID  \
# 0         5897        36243       67361                Air  srintship  5897
# 1         2360        89467       46954                Air  srintship  2360
# 2         6209        40597       76987               Land  srintship  6209
# 3         1480        90942       82830                Air  srintship  1480
# 4         2887        11790       83982               Land  srintship  2887
# 5         2838        20226       49955                Air  srintship  2838
# 6         8010        52160       41072                Air  srintship  8010
# 7         8144        86580       21359                Sea  srintship  8144
# 8         2907        30692       67361                Sea  srintship  2907
# 9         4214        46894       31857                Sea  srintship  4214
# 10        1388        70468       86308                Sea  srintship  1388
# 11        5718        13362       62821                Sea  srintship  5718
# 12        1851        72315       25889                Air  srintship  1851
# 13        2396        61570       23228                Sea  srintship  2396
# 14        4671        10731       47196                Air  srintship  4671
# 15        2067        19072       41879                Air  srintship  2067
# 16        1441        13362       14965                Air  srintship  1441
# 17        6466        96293       56575                Air  srintship  6466
# 18        5025        92698       49955               Land  srintship  5025
# 19        3521        68814       31857               Land  srintship  3521
# 20        2252        13951       34779               Land  srintship  2252
# 21        2742        74432       73217                Air  srintship  2742
# 22        9818        61570       75619                Sea  srintship  9818
# 23        8335        76443       47196                Sea  srintship  8335
# 24        3258        81423       35367               Land  srintship  3258
# 25        3678        16265       75353                Air  srintship  3678
# 26        6542        52647       29540               Land  srintship  6542
# 27        8929        76443       28960                Sea  srintship  8929
# 28        1058        55787       78981               Land  srintship  1058
# 29        8155        75444       61892               Land  srintship  8155
# 30        9456        21166       82777                Sea  srintship  9456
# 31        4147        42179       40164               Land  srintship  4147
# 32        3070        87695       74653                Air  srintship  3070
# 33        1451        46942       66663                Air  srintship  1451
# 34        9313        10731       64571                Air  srintship  9313
# 35        4524        24646       11854                Air  srintship  4524
# 36        3992        21232       65811                Air  srintship  3992
# 37        3614        81423       93440                Air  srintship  3614
# 38        2168        91465       17198               Land  srintship  2168
# 39        8893        40898       66663               Land  srintship  8893
# 40        4438        11186       89362               Land  srintship  4438
# 41        1310        15367       22049                Air  srintship  1310
# 42        4556        15367       94027                Air  srintship  4556
# 43        6843        40597       31412               Land  srintship  6843
# 44        9766        72315       40164               Land  srintship  9766
# 45        8522        10731       26336                Air  srintship  8522
# 46        4066        30864       76059               Land  srintship  4066
# 47        7103        13920       22940                Air  srintship  7103
# 48        8649        30864       62920                Air  srintship  8649
# 49        6673        19072       31857                Air  srintship  6673
# 50        3089        72315       90349                Air  srintship  3089
#
#    IntShip_id_type  Cluster
# 0              int        0
# 1              int        0
# 2              int        1
# 3              int        0
# 4              int        1
# 5              int        0
# 6              int        0
# 7              int        8
# 8              int        8
# 9              int        8
# 10             int        8
# 11             int        8
# 12             int        0
# 13             int        8
# 14             int        0
# 15             int        0
# 16             int        0
# 17             int        0
# 18             int        1
# 19             int        1
# 20             int        1
# 21             int        0
# 22             int        8
# 23             int        8
# 24             int        1
# 25             int        0
# 26             int        1
# 27             int        8
# 28             int        1
# 29             int        1
# 30             int        8
# 31             int        1
# 32             int        0
# 33             int        0
# 34             int        0
# 35             int        0
# 36             int        0
# 37             int        0
# 38             int        1
# 39             int        1
# 40             int        1
# 41             int        0
# 42             int        0
# 43             int        1
# 44             int        1
# 45             int        0
# 46             int        1
# 47             int        0
# 48             int        0
# 49             int        0
# 50             int        0
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17452\2502252675.py:100: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   model.fit(X)
# Node name: rcextship
# Node shape (rows,columns): (51, 7)
# Node dtypes: ExtShip_id                 int64
# factoryIds/retailerIds     int64
# idsTo                      int64
# TransportationType        object
# Label                     object
# ID                         int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['ExtShip_id', 'factoryIds/retailerIds', 'idsTo', 'ID', 'Label']
# Encoding....
# Model Fitting....
# Prediction Fitting...
# Node with cluster coulmn:
# d:\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1255: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
#     ExtShip_id  factoryIds/retailerIds  idsTo TransportationType      Label  \
# 0         2108                   63898  12666               Land  rcextship
# 1         6720                   26336  83792                Sea  rcextship
# 2         5965                   31857  16956               Land  rcextship
# 3         4536                   67158  45986                Air  rcextship
# 4         2575                   26654  64367               Land  rcextship
# 5         1281                   90345  84885                Air  rcextship
# 6         4492                   91089  50014               Land  rcextship
# 7         8644                   22049  90435               Land  rcextship
# 8         6650                   94027  21113                Sea  rcextship
# 9         1139                   45151  43022               Land  rcextship
# 10        3142                   49119  81118               Land  rcextship
# 11        8567                   56680  96548                Sea  rcextship
# 12        5916                   11854  66152               Land  rcextship
# 13        6604                   90345  85709               Land  rcextship
# 14        8328                   62821  60542                Sea  rcextship
# 15        5824                   28549  63479                Air  rcextship
# 16        5924                   67690  42770                Air  rcextship
# 17        2842                   62821  76264                Sea  rcextship
# 18        8699                   64571  80020               Land  rcextship
# 19        7945                   34083  41344                Air  rcextship
# 20        4078                   67690  24998                Sea  rcextship
# 21        1303                   63898  72646                Air  rcextship
# 22        6590                   60940  22228                Sea  rcextship
# 23        3064                   21359  32489               Land  rcextship
# 24        6256                   76954  13248               Land  rcextship
# 25        5806                   96831  14574               Land  rcextship
# 26        8708                   83982  14142               Land  rcextship
# 27        8104                   91089  82092                Sea  rcextship
# 28        1123                   56948  80996                Sea  rcextship
# 29        1912                   91326  22228                Air  rcextship
# 30        6277                   76384  87421                Sea  rcextship
# 31        2823                   48462  32819               Land  rcextship
# 32        2845                   38017  62831                Air  rcextship
# 33        2574                   14114  42770                Sea  rcextship
# 34        3496                   76059  48071               Land  rcextship
# 35        7747                   95444  18779                Air  rcextship
# 36        3770                   56948  21113                Air  rcextship
# 37        4965                   83982  48071                Sea  rcextship
# 38        4867                   57039  21478                Air  rcextship
# 39        2307                   75619  45986               Land  rcextship
# 40        1248                   83982  31548                Air  rcextship
# 41        9994                   52005  76264               Land  rcextship
# 42        7105                   18464  50653                Sea  rcextship
# 43        1331                   87755  47008                Air  rcextship
# 44        5941                   43964  96784                Air  rcextship
# 45        7217                   53380  79671               Land  rcextship
# 46        1410                   12318  65924                Air  rcextship
# 47        1264                   31412  12717               Land  rcextship
# 48        3238                   33250  42770               Land  rcextship
# 49        3852                   12318  82485                Sea  rcextship
# 50        8524                   61580  87252                Sea  rcextship
#
#       ID ExtShip_id_type  Cluster
# 0   2108             int        0
# 1   6720             int        1
# 2   5965             int        0
# 3   4536             int        2
# 4   2575             int        0
# 5   1281             int        2
# 6   4492             int        0
# 7   8644             int        0
# 8   6650             int        1
# 9   1139             int        0
# 10  3142             int        0
# 11  8567             int        1
# 12  5916             int        0
# 13  6604             int        0
# 14  8328             int        1
# 15  5824             int        2
# 16  5924             int        2
# 17  2842             int        1
# 18  8699             int        0
# 19  7945             int        2
# 20  4078             int        1
# 21  1303             int        2
# 22  6590             int        1
# 23  3064             int        0
# 24  6256             int        0
# 25  5806             int        0
# 26  8708             int        0
# 27  8104             int        1
# 28  1123             int        1
# 29  1912             int        2
# 30  6277             int        1
# 31  2823             int        0
# 32  2845             int        2
# 33  2574             int        1
# 34  3496             int        0
# 35  7747             int        2
# 36  3770             int        2
# 37  4965             int        1
# 38  4867             int        2
# 39  2307             int        0
# 40  1248             int        2
# 41  9994             int        0
# 42  7105             int        1
# 43  1331             int        2
# 44  5941             int        2
# 45  7217             int        0
# 46  1410             int        2
# 47  1264             int        0
# 48  3238             int        0
# 49  3852             int        1
# 50  8524             int        1
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Node name: scextship
# Node shape (rows,columns): (49, 7)
# Node dtypes: ExtShip_id                 int64
# factoryIds/retailerIds     int64
# idsTo                      int64
# TransportationType        object
# Label                     object
# ID                         int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['ExtShip_id', 'factoryIds/retailerIds', 'idsTo', 'ID', 'Label']
# Encoding....
# Model Fitting....
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17452\2502252675.py:100: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   model.fit(X)
# Prediction Fitting...
# Node with cluster coulmn:
# d:\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1255: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
#     ExtShip_id  factoryIds/retailerIds  idsTo TransportationType      Label  \
# 0         1456                   99762  15724                Sea  scextship
# 1         5089                   97142  91846                Air  scextship
# 2         7708                   26533  39892                Sea  scextship
# 3         7960                   48580  81782                Air  scextship
# 4         5028                   68240  27430                Air  scextship
# 5         4413                   23640  85900               Land  scextship
# 6         9033                   55787  69145                Air  scextship
# 7         3246                   13920  15307                Air  scextship
# 8         8786                   20226  48068               Land  scextship
# 9         1422                   55787  83792               Land  scextship
# 10        8588                   13951  22043               Land  scextship
# 11        7366                   21232  81344                Air  scextship
# 12        2490                   28873  33736                Air  scextship
# 13        6220                   99762  79381                Sea  scextship
# 14        6083                   21232  78934               Land  scextship
# 15        1988                   52647  33736               Land  scextship
# 16        5641                   35266  33597               Land  scextship
# 17        4456                   86815  78934               Land  scextship
# 18        3570                   52082  18065                Sea  scextship
# 19        8140                   21232  56182                Air  scextship
# 20        1431                   82144  42959                Sea  scextship
# 21        9590                   24451  11346               Land  scextship
# 22        5269                   29277  20571                Air  scextship
# 23        4227                   57551  41538                Sea  scextship
# 24        5333                   52082  24255                Air  scextship
# 25        8280                   16265  24998               Land  scextship
# 26        2379                   30692  58600                Air  scextship
# 27        8924                   52160  91846                Air  scextship
# 28        6062                   13920  91846                Air  scextship
# 29        5611                   36243  76264               Land  scextship
# 30        2983                   18997  65924               Land  scextship
# 31        1116                   46070  88373               Land  scextship
# 32        5717                   71916  14574               Land  scextship
# 33        9786                   68240  84885               Land  scextship
# 34        1903                   89467  78934                Air  scextship
# 35        8183                   77743  80020                Sea  scextship
# 36        2121                   18997  14259                Air  scextship
# 37        2177                   89467  42770                Sea  scextship
# 38        1876                   97142  78650                Air  scextship
# 39        9477                   75444  10613                Air  scextship
# 40        6449                   10161  22043               Land  scextship
# 41        8778                   71916  84885               Land  scextship
# 42        4781                   76443  59444               Land  scextship
# 43        2301                   76443  91447                Sea  scextship
# 44        3670                   21232  18451                Air  scextship
# 45        2269                   23640  21156                Sea  scextship
# 46        7218                   97142  29456                Sea  scextship
# 47        3429                   46204  70649                Air  scextship
# 48        4273                   68814  18213                Air  scextship
#
#       ID ExtShip_id_type  Cluster
# 0   1456             int        2
# 1   5089             int        0
# 2   7708             int        2
# 3   7960             int        0
# 4   5028             int        0
# 5   4413             int        4
# 6   9033             int        0
# 7   3246             int        0
# 8   8786             int        4
# 9   1422             int        4
# 10  8588             int        4
# 11  7366             int        0
# 12  2490             int        0
# 13  6220             int        2
# 14  6083             int        4
# 15  1988             int        4
# 16  5641             int        4
# 17  4456             int        4
# 18  3570             int        2
# 19  8140             int        0
# 20  1431             int        2
# 21  9590             int        4
# 22  5269             int        0
# 23  4227             int        2
# 24  5333             int        0
# 25  8280             int        4
# 26  2379             int        0
# 27  8924             int        0
# 28  6062             int        0
# 29  5611             int        4
# 30  2983             int        4
# 31  1116             int        4
# 32  5717             int        4
# 33  9786             int        4
# 34  1903             int        0
# 35  8183             int        2
# 36  2121             int        0
# 37  2177             int        2
# 38  1876             int        0
# 39  9477             int        0
# 40  6449             int        4
# 41  8778             int        4
# 42  4781             int        4
# 43  2301             int        2
# 44  3670             int        0
# 45  2269             int        2
# 46  7218             int        2
# 47  3429             int        0
# 48  4273             int        0
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Node name: ssintship
# Node shape (rows,columns): (537, 7)
# Node dtypes: IntShip_id             int64
# listSuppIds            int64
# factoryIds             int64
# TransportationType    object
# Label                 object
# ID                     int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['IntShip_id', 'listSuppIds', 'factoryIds', 'ID', 'Label']
# Encoding....
# Model Fitting....
# Prediction Fitting...
# Node with cluster coulmn:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17452\2502252675.py:100: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   model.fit(X)
# d:\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1255: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
#      IntShip_id  listSuppIds  factoryIds TransportationType      Label     ID  \
# 0          7281        90942       52160               Land  ssintship   7281
# 1          3477        87916       30692               Land  ssintship   3477
# 2          8796        90236       26533                Sea  ssintship   8796
# 3          2933        76443       51293                Air  ssintship   2933
# 4          3000        14125       68357               Land  ssintship   3000
# ..          ...          ...         ...                ...        ...    ...
# 532       10478        42179       46070                Sea  ssintship  10478
# 533       10479        48467       46070                Sea  ssintship  10479
# 534       10480        70468       18952                Air  ssintship  10480
# 535       10481        48580       18952               Land  ssintship  10481
# 536       10482        30864       18952                Air  ssintship  10482
#
#     IntShip_id_type  Cluster
# 0               int        1
# 1               int        1
# 2               int        6
# 3               int        0
# 4               int        1
# ..              ...      ...
# 532             int        6
# 533             int        6
# 534             int        0
# 535             int        1
# 536             int        0
#
# [537 rows x 8 columns]
# Node name: internalservices
# Node shape (rows,columns): (100, 10)
# Node dtypes: IntServ_id         int64
# IntTrans_id        int64
# placed_when       object
# actual_date       object
# expected_date     object
# quota            float64
# status            object
# Label             object
# ID                 int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['IntServ_id', 'IntTrans_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#     IntServ_id  IntTrans_id placed_when actual_date expected_date    quota  \
# 0         5822         5738  1971-03-20  1971-04-03    1971-04-19     7.20
# 1         9032         1952  1985-07-11  1985-08-01    1985-07-27     2.65
# 2         6669         4782  1987-07-14  1987-08-12    1987-08-07     3.64
# 3         1165         8659  2000-08-31  2000-09-11    2000-09-24  1248.57
# 4         7448         4782  1988-01-11  1988-02-05    1988-02-09    17.11
# ..         ...          ...         ...         ...           ...      ...
# 95        9334         4502  2017-02-28  2017-03-13    2017-03-13   861.82
# 96        5599         3581  1973-05-05  1973-05-26    1973-05-21   902.96
# 97        3103         1793  1988-06-22  1988-07-18    1988-07-13    60.33
# 98        4859         6220  2000-05-01  2000-05-14    2000-05-16  9866.19
# 99        5732         5792  1997-04-03  1997-04-15    1997-04-19     3.74
#
#        status             Label    ID IntServ_id_type  Cluster
# 0   Processed  internalservices  5822             int       22
# 1     Pending  internalservices  9032             int       10
# 2     Pending  internalservices  6669             int       10
# 3   Processed  internalservices  1165             int       14
# 4   Processed  internalservices  7448             int       22
# ..        ...               ...   ...             ...      ...
# 95  Processed  internalservices  9334             int       18
# 96    Pending  internalservices  5599             int       15
# 97    Pending  internalservices  3103             int       28
# 98  Processed  internalservices  4859             int       12
# 99  Processed  internalservices  5732             int       22
#
# [100 rows x 11 columns]
# Node name: rcextorders
# Node shape (rows,columns): (52, 12)
# Node dtypes: ExtOrders_id       int64
# ExtShip_id         int64
# quantity           int64
# placed_when       object
# actual_date       object
# expected_date     object
# cost             float64
# status            object
# prod_id            int64
# Label             object
# ID                 int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['ExtOrders_id', 'ExtShip_id', 'prod_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# Prediction Fitting...
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Node with cluster coulmn:
#     ExtOrders_id  ExtShip_id  quantity placed_when          actual_date  \
# 0           4444        7105       222  1990-12-23              Unknown
# 1           8666        7217       515  1979-01-24  1979-02-14 00:00:00
# 2           1414        2575       436  1982-04-29              Unknown
# 3           1321        8699       308  1984-11-12  1984-12-12 00:00:00
# 4           5984        8644       440  1982-09-02              Unknown
# 5           1932        2845       167  2020-09-16              Unknown
# 6           8691        8699       522  1990-10-31              Unknown
# 7           7793        8644       583  1972-04-22              Unknown
# 8           9035        2845       618  1992-10-16              Unknown
# 9           3622        7945       136  1979-05-10  1979-05-29 00:00:00
# 10          7702        2575       172  1987-09-26  1987-10-09 00:00:00
# 11          3889        1139       280  1985-08-21  1985-09-16 00:00:00
# 12          3158        6720       978  2001-01-08  2001-01-18 00:00:00
# 13          4784        8328       270  1977-03-27              Unknown
# 14          4210        2842       979  1974-12-01              Unknown
# 15          9638        7747       224  1985-10-09              Unknown
# 16          4419        1248       799  2015-10-31              Unknown
# 17          8077        8708       483  2002-03-24  2002-04-20 00:00:00
# 18          3828        8644       967  2009-02-14  2009-03-07 00:00:00
# 19          2221        3142       725  1975-01-14              Unknown
# 20          7987        5924       465  2014-03-17              Unknown
# 21          4759        6650       699  1978-09-17              Unknown
# 22          2788        3142       593  1987-08-12              Unknown
# ...
# expected_date     object
# cost             float64
# status            object
# prod_id            int64
# Label             object
# ID                 int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['IntOrders_id', 'IntShip_id', 'prod_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# Prediction Fitting...
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Node with cluster coulmn:
#     IntOrders_id  IntShip_id  quantity placed_when          actual_date  \
# 0           8605        2360       766  1993-05-08  1993-05-30 00:00:00
# 1           3057        1388       771  2007-10-29  2007-11-08 00:00:00
# 2           7340        9456       870  2000-07-24  2000-08-07 00:00:00
# 3           1532        8335       127  2009-06-07              Unknown
# 4           2409        9313       560  2017-06-07  2017-06-18 00:00:00
# ..           ...         ...       ...         ...                  ...
# 69          9959        1310       844  1993-05-08  1993-05-30 00:00:00
# 70          9960        4556       176  1993-05-08  1993-05-30 00:00:00
# 71          9961        6843       164  1993-05-08  1993-05-30 00:00:00
# 72          9963        6673       467  1993-05-08  1993-05-30 00:00:00
# 73          9964        3089       877  1993-05-08  1993-05-30 00:00:00
#
#    expected_date        cost            status  prod_id        Label    ID  \
# 0     1993-06-01     6794.42            Closed      438  srintorders  8605
# 1     2007-11-16  6800366.49            Closed      772  srintorders  3057
# 2     2000-08-03   536720.40           Delayed      831  srintorders  7340
# 3     2009-07-05      340.36  Out For Delivery      938  srintorders  1532
# 4     2017-07-04    35565.60            Closed      366  srintorders  2409
# ..           ...         ...               ...      ...          ...   ...
# 69    1993-06-01    59679.24            Closed      897  srintorders  9959
# 70    1993-06-01    12444.96            Closed      897  srintorders  9960
# 71    1993-06-01  1154701.04            Closed      990  srintorders  9961
# 72    1993-06-01  3333623.46            Closed      561  srintorders  9963
# 73    1993-06-01  4051371.66            Closed      259  srintorders  9964
#
#    IntOrders_id_type  Cluster
# 0                int        8
# 1                int       16
# 2                int       31
# 3                int       27
# 4                int       22
# ..               ...      ...
# 69               int        8
# 70               int        1
# 71               int        1
# 72               int        5
# 73               int        5
#
# [74 rows x 13 columns]
# Node name: scextorders
# Node shape (rows,columns): (48, 12)
# Node dtypes: ExtOrders_id       int64
# ExtShip_id         int64
# quantity           int64
# placed_when       object
# actual_date       object
# expected_date     object
# cost             float64
# status            object
# prod_id            int64
# Label             object
# ID                 int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['ExtOrders_id', 'ExtShip_id', 'prod_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#     ExtOrders_id  ExtShip_id  quantity placed_when          actual_date  \
# 0           9052        3429       217  1980-08-10              Unknown
# 1           5139        9786       284  2008-07-27  2008-08-17 00:00:00
# 2           8454        1456       409  2010-07-09  2010-08-03 00:00:00
# 3           4453        3246       948  1977-02-05              Unknown
# 4           5311        8924       983  2003-10-31              Unknown
# 5           5650        2269       268  1978-09-22  1978-10-08 00:00:00
# 6           4806        8588       546  1993-06-18  1993-07-17 00:00:00
# 7           6681        2379       730  1981-10-31              Unknown
# 8           4718        1431       692  1991-02-21              Unknown
# 9           4479        9477       493  1992-10-10  1992-10-30 00:00:00
# 10          5183        2379       583  2013-06-28  2013-07-19 00:00:00
# 11          4926        2121       600  1986-04-26              Unknown
# 12          9507        2269       509  1989-08-12  1989-08-29 00:00:00
# 13          3871        4456       186  1980-04-08              Unknown
# 14          8782        6220       578  2020-04-22  2020-05-13 00:00:00
# 15          2718        7366       789  1989-10-20  1989-11-13 00:00:00
# 16          1738        8140       988  1983-03-18              Unknown
# 17          8174        4781       886  1970-11-12  1970-12-02 00:00:00
# 18          3104        9786       438  1992-03-04  1992-04-02 00:00:00
# 19          6786        1876       308  1977-02-12              Unknown
# 20          4823        1456       145  1973-11-05  1973-11-27 00:00:00
# 21          7762        6083       954  2001-02-28              Unknown
# 22          6448        2121       989  1971-07-12              Unknown
# 23          7889        1431       509  1992-05-25              Unknown
# 24          2563        5269       869  1993-07-27  1993-08-23 00:00:00
# 25          9772        1988       772  2021-01-08  2021-01-28 00:00:00
# 26          1848        4227       815  2019-12-07              Unknown
# 27          4730        5641       471  2008-12-05  2008-12-28 00:00:00
# 28          7545        6220       158  1996-06-23              Unknown
# 29          2232        2490       372  2012-09-07  2012-09-27 00:00:00
# 30          6722        6062       838  2001-09-29  2001-10-10 00:00:00
# 31          3115        8924       153  1996-02-26  1996-03-15 00:00:00
# 32          5531        3246       448  1999-01-01              Unknown
# 33          2261        2177       225  1981-06-14              Unknown
# 34          5443        6220       321  1972-07-31              Unknown
# 35          9064        9477       295  1983-12-09  1983-12-29 00:00:00
# 36          6082        8786       994  2006-04-15  2006-05-05 00:00:00
# 37          3801        7960       574  2020-03-08              Unknown
# 38          5957        4456       371  2015-09-27              Unknown
# 39          1798        6062       758  1970-10-26  1970-11-24 00:00:00
# 40          5688        5717       349  1988-12-02  1989-01-01 00:00:00
# 41          3805        2490       810  2006-06-27  2006-07-18 00:00:00
# 42          5109        2121       745  1973-09-14  1973-10-02 00:00:00
# 43          7571        8140       494  1980-04-28  1980-05-20 00:00:00
# 44          4710        2490       349  1980-04-07              Unknown
# 45          7112        4227       688  2006-03-19              Unknown
# 46          8940        7218       706  2002-01-30  2002-02-19 00:00:00
# 47          9561        4227       980  2014-02-21              Unknown
#
#    expected_date        cost            status  prod_id        Label    ID  \
# 0     1980-08-26  1779786.26  Out For Delivery      786  scextorders  9052
# 1     2008-08-23    23813.40            Closed      856  scextorders  5139
# 2     2010-08-05     5570.58            Closed      801  scextorders  8454
# 3     1977-02-27   440706.24  Out For Delivery      534  scextorders  4453
# 4     2003-11-25    98024.76  Out For Delivery      767  scextorders  5311
# 5     1978-10-08  1913176.96            Closed      925  scextorders  5650
# 6     1993-07-02  2489967.48           Delayed      281  scextorders  4806
# 7     1981-11-14  7241694.90  Out For Delivery      492  scextorders  6681
# 8     1991-03-16    74313.88  Out For Delivery      316  scextorders  4718
# 9     1992-11-07  3527893.21            Closed      446  scextorders  4479
# 10    2013-07-28  5783435.79            Closed      492  scextorders  5183
# 11    1986-05-12  1073874.00  Out For Delivery      376  scextorders  4926
# 12    1989-09-08   365151.51            Closed      391  scextorders  9507
# 13    1980-04-21   139728.78  Out For Delivery      115  scextorders  3871
# 14    2020-05-18     7872.36            Closed      801  scextorders  8782
# 15    1989-11-10   172151.91           Delayed      977  scextorders  2718
# 16    1983-03-28   215571.72  Out For Delivery      977  scextorders  1738
# 17    1970-11-27     2374.48           Delayed      938  scextorders  8174
# 18    1992-03-18    36726.30           Delayed      856  scextorders  3104
# 19    1977-02-27  1521101.12  Out For Delivery      759  scextorders  6786
# 20    1973-12-04     1974.90            Closed      801  scextorders  4823
# 21    2001-03-12   208153.26  Out For Delivery      977  scextorders  7762
# 22    1971-08-01   424211.77  Out For Delivery      372  scextorders  6448
# 23    1992-06-21    54661.51  Out For Delivery      316  scextorders  7889
# 24    1993-08-26  7513156.75            Closed      320  scextorders  2563
# 25    2021-01-19   309116.52           Delayed      967  scextorders  9772
# 26    2019-12-17    71263.60  Out For Delivery      133  scextorders  1848
# 27    2008-12-30  3051024.96            Closed      710  scextorders  4730
# 28    1996-07-20     2151.96  Out For Delivery      801  scextorders  7545
# 29    2012-09-23    32192.88           Delayed      675  scextorders  2232
# 30    2001-10-10   389569.44            Closed      534  scextorders  6722
# 31    1996-03-27      582.93            Closed      956  scextorders  3115
# 32    1999-01-26   208266.24  Out For Delivery      534  scextorders  5531
# 33    1981-06-28     1903.50  Out For Delivery      328  scextorders  2261
# 34    1972-08-15     4372.02  Out For Delivery      801  scextorders  5443
# 35    1984-01-03  2111011.15            Closed      446  scextorders  9064
# 36    2006-05-08     2872.66            Closed      907  scextorders  6082
# 37    2020-04-02   266841.12  Out For Delivery      534  scextorders  3801
# 38    2015-10-14    78848.63  Out For Delivery      778  scextorders  5957
# 39    1970-11-19   352379.04           Delayed      534  scextorders  1798
# 40    1988-12-17    16451.86           Delayed      549  scextorders  5688
# 41    2006-07-19    70097.40            Closed      675  scextorders  3805
# 42    1973-10-07  3985846.85            Closed      809  scextorders  5109
# 43    1980-05-23   107785.86            Closed      977  scextorders  7571
# 44    1980-05-05    30202.46  Out For Delivery      675  scextorders  4710
# 45    2006-04-16   308506.08  Out For Delivery      417  scextorders  7112
# 46    2002-02-12   483588.82           Delayed      422  scextorders  8940
# 47    2014-03-04   416157.00  Out For Delivery      573  scextorders  9561
#
#    ExtOrders_id_type  Cluster
# 0                int       30
# 1                int       22
# 2                int        0
# 3                int        1
# 4                int        1
# 5                int       10
# 6                int       18
# 7                int        9
# 8                int        2
# 9                int       28
# 10               int       14
# 11               int        2
# 12               int       17
# 13               int        5
# 14               int       20
# 15               int       31
# 16               int        1
# 17               int       16
# 18               int       21
# 19               int       30
# 20               int       29
# 21               int        1
# 22               int        1
# 23               int       24
# 24               int        3
# 25               int        4
# 26               int        1
# 27               int        6
# 28               int        5
# 29               int       26
# 30               int       13
# 31               int        7
# 32               int       24
# 33               int        5
# 34               int       24
# 35               int       15
# 36               int       23
# 37               int        2
# 38               int       24
# 39               int       19
# 40               int        8
# 41               int       25
# 42               int       11
# 43               int       27
# 44               int       24
# 45               int        2
# 46               int       12
# 47               int        1
# Node name: ssintorders
# Node shape (rows,columns): (548, 12)
# Node dtypes: IntOrders_id       int64
# IntShip_id         int64
# quantity           int64
# placed_when       object
# actual_date       object
# expected_date     object
# cost             float64
# status            object
# prod_id            int64
# Label             object
# ID                 int64
# dtype: object
# Node specifc dtypes: {}
# Columns to remove: []
# Ignoring id columns +others...
# ['IntOrders_id', 'IntShip_id', 'prod_id', 'ID', 'Label']
# Scaling....
# Encoding....
# Model Fitting....
# d:\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Prediction Fitting...
# Node with cluster coulmn:
#      IntOrders_id  IntShip_id  quantity placed_when          actual_date  \
# 0            6266        6224       438  1975-01-08              Unknown
# 1            5318        6798       801  2021-01-18  2021-02-07 00:00:00
# 2            2439        8796       882  1978-07-09              Unknown
# 3            1851        4895       220  2002-12-28              Unknown
# 4            9800        3996       399  1975-10-06              Unknown
# ..            ...         ...       ...         ...                  ...
# 543         10448       10478       440  1993-05-08  1993-05-30 00:00:00
# 544         10449       10479       961  1993-05-08  1993-05-30 00:00:00
# 545         10450       10480       880  1993-05-08  1993-05-30 00:00:00
# 546         10451       10481        92  1993-05-08  1993-05-30 00:00:00
# 547         10452       10482       451  1993-05-08  1993-05-30 00:00:00
#
#     expected_date        cost            status  prod_id        Label     ID  \
# 0      1975-02-01    30966.60  Out For Delivery      883  ssintorders   6266
# 1      2021-01-29  2474032.68           Delayed      911  ssintorders   5318
# 2      1978-07-28  1789727.94  Out For Delivery      679  ssintorders   2439
# 3      2003-01-22   109498.40  Out For Delivery      779  ssintorders   1851
# 4      1975-10-29   867382.11  Out For Delivery      926  ssintorders   9800
# ..            ...         ...               ...      ...          ...    ...
# 543    1993-06-01  3880505.20            Closed      354  ssintorders  10448
# 544    1993-06-01    75438.50            Closed      270  ssintorders  10449
# 545    1993-06-01     1117.60            Closed      812  ssintorders  10450
# 546    1993-06-01    42768.96            Closed      534  ssintorders  10451
# 547    1993-06-01    46601.83            Closed      576  ssintorders  10452
#
#     IntOrders_id_type  Cluster
# 0                 int       12
# 1                 int       16
# 2                 int        6
# 3                 int       12
# 4                 int       12
# ..                ...      ...
# 543               int        9
# 544               int        3
# 545               int        3
# 546               int        1
# 547               int        4
#
# [548 rows x 13 columns]

# %% [markdown]
# ## Visualization

# %%
myplot=train_data["supplier"]

# plt.plot(train_data["supplier"]["ID"].to_list(),train_data["supplier"]["Cluster"],'o--')
# plt.xlabel("ID")
# plt.ylabel("Cluster")

sns.scatterplot(data=myplot, x="ID", y="market_share (%)" ,hue='Cluster',palette=sns.color_palette("hls",10),
               legend="full")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17452\2551378409.py:7: UserWarning:
# The palette list has fewer values (10) than needed (32) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(data=myplot, x="ID", y="market_share (%)" ,hue='Cluster',palette=sns.color_palette("hls",10),
# <Axes: xlabel='ID', ylabel='market_share (%)'>

# %%
# for k,v in train_data.items():
#     plt.figure()
#     plt.title(k + " node")
#     plt.plot(list(train_data[k].iloc[:, 0]),train_data[k]['Cluster'].to_list(),'o--')
#     plt.xlabel("ID")
#     plt.ylabel("Cluster")
#     plt.show()

for k, v in train_data.items():
    plt.figure()
    plt.title(k + " node")
    sns.scatterplot(x=train_data[k].iloc[:, 0], y=train_data[k]['Cluster'], marker='o', linestyle='--')
    plt.xlabel("ID")
    plt.ylabel("Cluster")
    plt.show()
